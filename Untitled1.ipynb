# %% [markdown]
# ## read file and give the ans
# - Find webpage title.
# - Find all product names.
# - Find all prices.
# - Find all ratings.
# - Find all brands.
# - Count total products.
# - Print only first product name.
# - Print only last product price.
# - Find all image sources.
# - Extract all categories.
# - Find the ID of categories list.
# - Find product with highest price.
# - Find products with rating above 4.3.
# - Extract complete details of all products.
# - Print all text from webpage.
# - Convert data into Python list.
# - Convert data into Pandas DataFrame.
# - Save data into CSV file.
# - Find all <div> tags with class product.
# - Extract product name + price together.

# %%
import pandas as pd 
import numpy as np
from bs4 import BeautifulSoup

# %%
with open("preview.html",encoding='utf-8') as file:
    content=file.read()
soup=BeautifulSoup(content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Online Shopping Store</title>
# </head>
# <body>
# <h1 id="store-name">Welcome to Online Shopping Store</h1>
# <div class="product">
# <img alt="Laptop" src="laptop.jpg"/>
# <h2 class="product-name">HP Laptop</h2>
# <p class="brand">Brand: HP</p>
# <p class="price">Price: ₹55000</p>
# <p class="rating">Rating: 4.5</p>
# </div>
# <div class="product">
# <img alt="Mobile" src="mobile.jpg"/>
# <h2 class="product-name">iPhone 15</h2>
# <p class="brand">Brand: Apple</p>
# <p class="price">Price: ₹80000</p>
# <p class="rating">Rating: 4.8</p>
# </div>
# <div class="product">
# <img alt="Headphone" src="headphone.jpg"/>
# <h2 class="product-name">Boat Headphones</h2>
# <p class="brand">Brand: Boat</p>
# <p class="price">Price: ₹2500</p>
# <p class="rating">Rating: 4.2</p>
# </div>
# <div class="product">
# <img alt="Watch" src="watch.jpg"/>
# <h2 class="product-name">Smart Watch</h2>
# ...

# %% [markdown]
# ## 1)
# - Find webpage title.
# - Find all product names.
# - Find all prices.
# - Find all ratings.
# - Find all brands.

# %%
product=soup.find_all("div",class_="product")
print(product)
# Out:
# [<div class="product">
# <img alt="Laptop" src="laptop.jpg"/>
# <h2 class="product-name">HP Laptop</h2>
# <p class="brand">Brand: HP</p>
# <p class="price">Price: ₹55000</p>
# <p class="rating">Rating: 4.5</p>
# </div>, <div class="product">
# <img alt="Mobile" src="mobile.jpg"/>
# <h2 class="product-name">iPhone 15</h2>
# <p class="brand">Brand: Apple</p>
# <p class="price">Price: ₹80000</p>
# <p class="rating">Rating: 4.8</p>
# </div>, <div class="product">
# <img alt="Headphone" src="headphone.jpg"/>
# <h2 class="product-name">Boat Headphones</h2>
# <p class="brand">Brand: Boat</p>
# <p class="price">Price: ₹2500</p>
# <p class="rating">Rating: 4.2</p>
# </div>, <div class="product">
# <img alt="Watch" src="watch.jpg"/>
# <h2 class="product-name">Smart Watch</h2>
# <p class="brand">Brand: Noise</p>
# <p class="price">Price: ₹4000</p>
# <p class="rating">Rating: 4.0</p>
# </div>, <div class="product">
# <img alt="Tablet" src="tablet.jpg"/>
# ...

# %%
for i in product:
    name=soup.find("h2",class_="product-name").get_text(strip=True)
    print(name)
# Out:
# HP Laptop
# HP Laptop
# HP Laptop
# HP Laptop
# HP Laptop
